# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel("iau.xlsx")

# %%
df
# Out:
#                                     PROGRAM ADI  KONTENJAN  TABAN PUAN  \
# 0                        Adalet (%50 İndirimli)         29     253.090
# 1                               Adalet (Burslu)          7     290.783
# 2                   Adalet (İÖ) (%50 İndirimli)         43     214.295
# 3                          Adalet (İÖ) (Burslu)          7     286.292
# 4                              Adalet (Ücretli)         13     182.300
# ..                                          ...        ...         ...
# 359   Yazılım Mühendisliği (İngilizce) (Burslu)         11         NaN
# 360      Yeni Medya ve İletişim (%50 İndirimli)         38     250.549
# 361             Yeni Medya ve İletişim (Burslu)          6     337.291
# 362  Yönetim Bilişim Sistemleri (%50 İndirimli)         59     245.212
# 363         Yönetim Bilişim Sistemleri (Burslu)         11     317.652
#
#      BAŞARI SIRASI
# 0         757375.0
# 1         416374.0
# 2        1240158.0
# 3         447377.0
# ...

# %%
df.fillna(value='Bilinmiyor').update
# Out:
# <bound method DataFrame.update of                                     PROGRAM ADI  KONTENJAN  TABAN PUAN  \
# 0                        Adalet (%50 İndirimli)         29      253.09
# 1                               Adalet (Burslu)          7     290.783
# 2                   Adalet (İÖ) (%50 İndirimli)         43     214.295
# 3                          Adalet (İÖ) (Burslu)          7     286.292
# 4                              Adalet (Ücretli)         13       182.3
# ..                                          ...        ...         ...
# 359   Yazılım Mühendisliği (İngilizce) (Burslu)         11  Bilinmiyor
# 360      Yeni Medya ve İletişim (%50 İndirimli)         38     250.549
# 361             Yeni Medya ve İletişim (Burslu)          6     337.291
# 362  Yönetim Bilişim Sistemleri (%50 İndirimli)         59     245.212
# 363         Yönetim Bilişim Sistemleri (Burslu)         11     317.652
#
#     BAŞARI SIRASI
# 0        757375.0
# 1        416374.0
# 2       1240158.0
# ...

# %%
df
# Out:
#                                     PROGRAM ADI  KONTENJAN  TABAN PUAN  \
# 0                        Adalet (%50 İndirimli)         29     253.090
# 1                               Adalet (Burslu)          7     290.783
# 2                   Adalet (İÖ) (%50 İndirimli)         43     214.295
# 3                          Adalet (İÖ) (Burslu)          7     286.292
# 4                              Adalet (Ücretli)         13     182.300
# ..                                          ...        ...         ...
# 359   Yazılım Mühendisliği (İngilizce) (Burslu)         11         NaN
# 360      Yeni Medya ve İletişim (%50 İndirimli)         38     250.549
# 361             Yeni Medya ve İletişim (Burslu)          6     337.291
# 362  Yönetim Bilişim Sistemleri (%50 İndirimli)         59     245.212
# 363         Yönetim Bilişim Sistemleri (Burslu)         11     317.652
#
#      BAŞARI SIRASI
# 0         757375.0
# 1         416374.0
# 2        1240158.0
# 3         447377.0
# ...
