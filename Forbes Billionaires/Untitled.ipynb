# %%
import pandas as pd
import numpy as np

# %%
billioner=pd.read_csv("Forbes Billionaires.csv")

# %%
billioner
# Out:
#       Rank                        Name  Networth  Age        Country  \
# 0         1                 Elon Musk      219.0   50  United States
# 1         2                Jeff Bezos      171.0   58  United States
# 2         3  Bernard Arnault & family      158.0   73         France
# 3         4                Bill Gates      129.0   66  United States
# 4         5            Warren Buffett      118.0   91  United States
# ...     ...                        ...       ...  ...            ...
# 2595   2578    Jorge Gallardo Ballart        1.0   80          Spain
# 2596   2578              Nari Genomal        1.0   82    Philippines
# 2597   2578            Ramesh Genomal        1.0   71    Philippines
# 2598   2578            Sunder Genomal        1.0   68    Philippines
# 2599   2578     Horst-Otto Gerberding        1.0   69        Germany
#
#                       Source                Industry
# 0              Tesla, SpaceX             Automotive
# ...

# %%
billioner.head(10) #It reads First 10 bit (n is changable)
# Out:
#    Rank                        Name  Networth  Age        Country  \
# 0      1                 Elon Musk      219.0   50  United States
# 1      2                Jeff Bezos      171.0   58  United States
# 2      3  Bernard Arnault & family      158.0   73         France
# 3      4                Bill Gates      129.0   66  United States
# 4      5            Warren Buffett      118.0   91  United States
# 5      6                Larry Page      111.0   49  United States
# 6      7               Sergey Brin      107.0   48  United States
# 7      8             Larry Ellison      106.0   77  United States
# 8      9             Steve Ballmer       91.4   66  United States
# 9     10             Mukesh Ambani       90.7   64          India
#
#                Source                Industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# ...

# %%
len(billioner.index) #I can learn how many indexes are there in this dataset
# Out:
# 2600

# %%
billioner["Networth"].mean() #First İt rows Networth value if ı add .mean,I take the average
# Out:
# 4.860750000000006

# %%
billioner["Networth"].max()#Same as mean but this time I learned max Networth or value
# Out:
# 219.0

# %%
billioner["Networth"].max()
# Out:
# 219.0

# %%
billioner[billioner["Networth"]==billioner["Networth"].max()]["Name"].iloc[0] #I found the man with the highest Networth
# Out:
# 'Elon Musk '

# %%
billioner[billioner["Name"]=="Bernard Arnault & family"]["Country"] #Normalde İsmi Bernard arnault a eşit olanı çağırması gerekiyordu neden cağırmadı anlamadım
# Out:
# Series([], Name: Country, dtype: object)

# %%
billioner.groupby("Industry").mean() #I found the average of everything by industry
# Out:
#                                    Rank   Networth        Age
# Industry
# Automotive                   1168.623188  8.443478  63.449275
# Construction & Engineering   1518.558140  2.811628  65.116279
# Energy                       1177.204301  4.250538  67.107527
# Fashion & Retail             1210.711382  6.557724  67.325203
# Finance & Investments        1225.562176  4.493005  64.536269
# Food & Beverage              1193.213930  4.643532  65.800995
# Gambling & Casinos           1076.304348  4.678261  67.608696
# Healthcare                   1423.353774  3.343868  63.976415
# Logistics                    1186.228571  5.605714  67.628571
# Manufacturing                1383.208075  3.353416  63.583851
# Media & Entertainment        1255.200000  5.195789  63.063158
# Metals & Mining              1149.402985  5.816418  60.029851
# Real Estate                  1297.518519  3.628571  67.550265
# Service                      1286.058824  3.649020  68.058824
# ...

# %%
billioner["Industry"].nunique() #I found how many diffirent Industry are there in this dataset
# Out:
# 18

# %%
billioner["Industry"].value_counts() #Her endistüride kaç farklı kişi var
# Out:
# Finance & Investments          386
# Technology                     329
# Manufacturing                  322
# Fashion & Retail               246
# Healthcare                     212
# Food & Beverage                201
# Real Estate                    189
# diversified                    178
# Media & Entertainment           95
# Energy                          93
# Automotive                      69
# Metals & Mining                 67
# Service                         51
# Construction & Engineering      43
# Logistics                       35
# Telecom                         35
# Sports                          26
# Gambling & Casinos              23
# Name: Industry, dtype: int64

# %%
def mal_find(last_Name):
    if "mal" in last_Name.lower():   #Soyadlarında 'MAL' gecen indexleri buldum
        return True
    return False
billioner[billioner["Name"].apply(mal_find)]
# Out:
#       Rank                          Name  Networth  Age        Country  \
# 320     321                 John Malone        7.4   81  United States
# 701     687                Ajay Piramal        4.2   66          India
# 865     851  Mary Alice Dorrance Malone        3.5   72  United States
# 1219   1196                Nirmal Minda        2.6   64          India
# 1692   1645               Bill Malhotra        1.8   72         Canada
# 2018   1929               Rafique Malik        1.5   71          India
# 2596   2578                Nari Genomal        1.0   82    Philippines
# 2597   2578              Ramesh Genomal        1.0   71    Philippines
# 2598   2578              Sunder Genomal        1.0   68    Philippines
#
#                 Source                Industry
# 320   cable television  Media & Entertainment
# 701    pharmaceuticals             Healthcare
# 865      Campbell Soup        Food & Beverage
# 1219        auto parts             Automotive
# ...

# %%
print(billioner.tail()) #for viewing the last rows of the DataFrame.
# Out:
#       Rank                      Name  Networth  Age      Country  \
# 2595   2578  Jorge Gallardo Ballart        1.0   80        Spain
# 2596   2578            Nari Genomal        1.0   82  Philippines
# 2597   2578          Ramesh Genomal        1.0   71  Philippines
# 2598   2578          Sunder Genomal        1.0   68  Philippines
# 2599   2578   Horst-Otto Gerberding        1.0   69      Germany
#
#                       Source           Industry
# 2595         pharmaceuticals        Healthcare
# 2596                 apparel  Fashion & Retail
# 2597                 apparel  Fashion & Retail
# 2598                garments  Fashion & Retail
# 2599  flavors and fragrances   Food & Beverage

# %%
billioner.isnull().sum()
# Out:
# Rank        0
# Name        0
# Networth    0
# Age         0
# Country     0
# Source      0
# Industry    0
# dtype: int64
