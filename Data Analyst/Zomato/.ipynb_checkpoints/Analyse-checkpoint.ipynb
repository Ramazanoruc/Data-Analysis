# %% [markdown]
# <div style="padding: 20px;border-radius: 16px;background-color: #FF3CAC;
# background-image: linear-gradient(225deg, #FF3CAC 0%, #784BA0 50%, #2B86C5 100%);
# color: white;text-align:center;font-family: Inter,sans-serif;">
#         <h4 style="font-size: 24px;">Zomato Top 100 Cities Restaurant Data</h4>
#     </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('/kaggle/input/zomato-data-40k-restaurants-of-indias-100-cities/zomato_dataset.csv')

# %%
df
# Out:
#                            Restaurant Name Rating  \
# 0                            Campus Bakers    4.3
# 1           Mama Chicken Mama Franky House      4
# 2         GMB - Gopika Sweets & Restaurant    4.2
# 3      Shree Bankey Bihari Misthan Bhandar    4.2
# 4                              Burger King    4.2
# ...                                    ...    ...
# 44886                              Bowl 99      -
# 44887                           Vegan Mart      -
# 44888                        Biryani Plaza      -
# 44889                        Biryani Plaza      -
# 44890                        Biryani Plaza      -
#
#                                                  Cuisine Average Price  \
# 0             Bakery, Fast Food, Pizza, Sandwich, Burger   ₹50 for one
# 1            North Indian, Mughlai, Rolls, Burger, Momos   ₹50 for one
# 2      North Indian, South Indian, Chinese, Fast Food...   ₹50 for one
# 3      Mithai, Street Food, South Indian, Chinese, Ic...   ₹50 for one
# 4                           Burger, Fast Food, Beverages   ₹50 for one
# ...                                                  ...           ...
# 44886                                       North Indian  ₹350 for one
# 44887                                  Juices, Beverages  ₹350 for one
# 44888                                            Biryani  ₹350 for one
# 44889                                            Biryani  ₹350 for one
# 44890                                            Biryani  ₹350 for one
#
#         Average Delivery Time  \
# 0                      36 min
# 1                      22 min
# 2                      27 min
# 3                      28 min
# 4                      26 min
# ...                       ...
# 44886  Opens tomorrow at 11am
# 44887  Opens tomorrow at 11am
# 44888  Opens tomorrow at 11am
# 44889  Opens tomorrow at 11am
# 44890  Opens tomorrow at 11am
#
#                                           Safety Measure  Location
# 0                Restaurant partner follows WHO protocol      Agra
# 1      Follows all Max Safety measures to ensure your...      Agra
# 2      Follows all Max Safety measures to ensure your...      Agra
# 3                Restaurant partner follows WHO protocol      Agra
# 4      Follows all Max Safety measures to ensure your...      Agra
# ...                                                  ...       ...
# 44886  Follows all Max Safety measures to ensure your...  Warangal
# 44887  Follows all Max Safety measures to ensure your...  Warangal
# 44888  Follows all Max Safety measures to ensure your...  Warangal
# 44889  Follows all Max Safety measures to ensure your...  Warangal
# 44890  Follows all Max Safety measures to ensure your...  Warangal
#
# [44891 rows x 7 columns]

# %% [markdown]
# <div style="padding: 20px;border-radius: 16px;background-color: #FF3CAC;
# background-image: linear-gradient(225deg, #FF3CAC 0%, #784BA0 50%, #2B86C5 100%);
# color: white;text-align:center;font-family: Inter,sans-serif;">
#         <h4 style="font-size: 24px;">Data Cleaning</h4>
#     </div>

# %%
#The average price is replaced from 'â‚¹50 for one' to 50
df['Average Price'] = df['Average Price'].str.extract('(\d+)').fillna(0).astype(int)

# %%
df
# Out:
#                            Restaurant Name Rating  \
# 0                            Campus Bakers    4.3
# 1           Mama Chicken Mama Franky House      4
# 2         GMB - Gopika Sweets & Restaurant    4.2
# 3      Shree Bankey Bihari Misthan Bhandar    4.2
# 0                Restaurant partner follows WHO protocol      Agra
# 1      Follows all Max Safety measures to ensure your...      Agra
# 2      Follows all Max Safety measures to ensure your...      Agra
# 3                Restaurant partner follows WHO protocol      Agra
# 4      Follows all Max Safety measures to ensure your...      Agra
# ...                                                  ...       ...
# 44886  Follows all Max Safety measures to ensure your...  Warangal
# 44887  Follows all Max Safety measures to ensure your...  Warangal
# 44888  Follows all Max Safety measures to ensure your...  Warangal
# 44889  Follows all Max Safety measures to ensure your...  Warangal
# 44890  Follows all Max Safety measures to ensure your...  Warangal
#
# [44891 rows x 7 columns]

# %% [markdown]
# <div style="padding: 20px;border-radius: 16px;background-color: #FF3CAC;
# background-image: linear-gradient(225deg, #FF3CAC 0%, #784BA0 50%, #2B86C5 100%);
# color: white;text-align:center;font-family: Inter,sans-serif;">
#         <h4 style="font-size: 24px;">Exploratory Data Analysis (EDA)</h4>
#     </div>

# %%
df['Delivery Status'] = df['Average Delivery Time'].apply(lambda x: 'Open' if 'min' in str(x) else 'Closed')


delivery_counts = df['Delivery Status'].value_counts().reset_index()
delivery_counts.columns = ['Delivery Status', 'Count']

fig = px.pie(
    delivery_counts,
    names='Delivery Status',
    values='Count',
    title='Distribution of Open and Closed Restaurants',
    color_discrete_sequence=px.colors.qualitative.Pastel1,
    template='seaborn', 
)

fig.update_traces(textposition='outside')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="fab50b8d-2168-4762-b721-276e3370a0e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fab50b8d-2168-4762-b721-276e3370a0e7")) {                    Plotly.newPlot(                        "fab50b8d-2168-4762-b721-276e3370a0e7",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Delivery Status=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Open","Closed"],"legendgroup":"","name":"","showlegend":true,"values":[40210,4681],"type":"pie","textposition":"outside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},
]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411 ...

# %%
import matplotlib.pyplot as plt

df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')
df['Rating Category'] = df['Rating'].apply(lambda x: '0-3' if pd.isna(x) or x < 3 else ('3-4' if x < 4 else '4+'))
rating_counts = df['Rating Category'].value_counts()
colors = ['gold', 'lightcoral', 'lightskyblue']

plt.figure(figsize=(8, 8))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Distribution of Ratings')
plt.show()

# %%
#To find all the types of pricing in different restaurants
unique_prices = df['Average Price'].unique()
print(unique_prices)
# Out:
# [ 50 100 150 200 250 300 500 400 350 450  40   0 550  48   1 600  32 900
#  750 800 650  10  12 850   2]

# %%
#After getting the unique prices, we can divide them into different categories
unique_prices = [50, 100, 150, 200, 250, 300, 500, 400, 350, 450, 40, 0, 550, 48, 1, 600, 32, 900, 750, 800, 650, 10, 12, 850, 2]

# Define the price ranges
price_ranges = {
    'Less than 50': lambda x: x < 50,
    '100-200': lambda x: 100 <= x < 200,
    '200-300': lambda x: 200 <= x < 300,
    '300-400': lambda x: 300 <= x < 400,
    '400-500': lambda x: 400 <= x < 500,
    '500-700': lambda x: 500 <= x < 700,
    'Greater than 700': lambda x: x > 700
}

# Count the occurrences in each price range
price_counts = {range_name: sum(price_range(price) for price in unique_prices) for range_name, price_range in price_ranges.items()}


labels = price_counts.keys()
sizes = price_counts.values()

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  

plt.title('Distribution of Average Prices')
plt.show()

# %%
#To find all possible Cuisine in the dataset
cuisine_column = df['Cuisine']

all_cuisines = [cuisine.split(', ') for cuisine in cuisine_column if pd.notna(cuisine)]
unique_cuisines = set([c for sublist in all_cuisines for c in sublist])

print("All Possible Cuisines:", unique_cuisines)
# Out:
# All Possible Cuisines: {'Vietnamese', '', 'Tea', 'Indonesian', 'Pizza', 'Singaporean', 'Cantonese', 'Desserts', 'Turkish', 'Mexican', 'Salad', 'Rolls', 'Charcoal Chicken', 'Mithai', 'Bakery', 'Andhra', 'Bengali', 'Grilled Chicken', 'Gujarati', 'Afghan', 'Beverages', 'Lucknowi', 'Assamese', 'Japanese', 'Mandi', 'Drinks Only', 'Goan', 'Kathiyawadi', 'Momos', 'Beverages,', 'Italian', 'Russian', 'Indian', 'Iranian', 'Steak', 'Modern Indian', 'Cuisine Varies', 'French', 'Desserts,', 'Greek', 'Biryani', 'Ice Cream', 'Saoji', 'Maharashtrian', 'Bohri', 'Panini', 'Hot dogs', 'South Indian', 'Nepalese', 'Bar Food', 'Raw Meats', 'Continental', 'Lebanese', 'Sindhi', 'Bubble Tea', 'Frozen Yogurt', 'Oriental', 'Finger Food', 'Cafe', 'Malaysian', 'Awadhi', 'Himachali', 'BBQ', 'Hyderabadi', 'North Indian', 'American', 'Waffle', 'European', 'Sushi', 'Thai', 'Bihari', 'Odia', 'Fast Food', 'Parsi', 'Bakery,', 'Asian', 'Chinese', 'Pancake', 'Belgian', 'Chettinad', 'Street Food', 'Mangalorean', 'Mongolian', 'Coffee', 'Konkan', 'Spanish', 'Malwani', 'Roast Chicken', 'Seafood', 'North Eastern', 'Tamil', 'Mughlai', 'Arabian', 'Kashmiri', 'Kebab', 'Tibetan', 'Kerala', 'Mediterranean', 'Burmese', 'Garhwali', 'Rajasthani', 'Pasta', 'Afghani', 'Wraps', 'Korean', 'Healthy Food', 'Paan', 'Poké', 'Sandwich', 'Brazilian', 'Mishti', 'Manipuri', 'Naga', 'Portuguese', 'Sri Lankan', 'Burger', 'Tex-Mex', 'German', 'African', 'Moroccan', 'Middle Eastern', 'Juices', 'Egyptian', 'Shawarma', 'Sichuan', 'Cake', 'Bangladeshi', 'Shake'}

# %%
import pandas as pd
import plotly.express as px

cuisine_counts = df['Cuisine'].str.split(', ').explode().value_counts()
top_15_cuisines = cuisine_counts.head(15)
plot_data = pd.DataFrame({'Cuisine': top_15_cuisines.index, 'Frequency': top_15_cuisines.values})
colors = px.colors.qualitative.Set3

fig = px.bar(plot_data, x='Frequency', y='Cuisine', color='Cuisine',
             color_discrete_sequence=colors,
             orientation='h', labels={'Frequency': 'Frequency'},
             title='Top 15 Cuisines', width=800, height=500)

fig.update_layout(showlegend=False)  
fig.show()
# Out:
# <div>                            <div id="1456ab5a-72df-4f1a-a3d2-bae3d8808cee" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1456ab5a-72df-4f1a-a3d2-bae3d8808cee")) {                    Plotly.newPlot(                        "1456ab5a-72df-4f1a-a3d2-bae3d8808cee",                        [{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North Indian","marker":{"color":"rgb(141,211,199)","pattern":{"shape":""}},"name":"North Indian","offsetgroup":"North Indian","orientation":"h","showlegend":true,"textposition":"auto","x":[18232],"xaxis":"x","y":["North Indian"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fast Food","marker":{"color":"rgb(255,255,179)","pattern":{"shape":""}},"name":"Fast Food","offsetgroup":"Fast Food","orientation":"h","showlegend":true,"textposition":"auto","x":[15932],"xaxis":"x","y":["Fast Food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chinese","marker":{"color":"rgb(190,186,218)","pattern":{"shape":""}},"name":"Chinese","offsetgroup":"Chinese","orientation":"h","showlegend":true,"textposition":"auto","x":[15275],"xaxis":"x","y":["Chinese"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beverages","marker":{"color":"rgb(251,128,114)","pattern":{"shape":""}},"name":"Beverages","offsetgroup":"Beverages","orientation":"h","showlegend":true,"textposition":"auto","x":[12988],"xaxis":"x","y":["Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Desserts","marker":{"color":"rgb(128,177,211)","pattern":{"shape":""}},"name":"Desserts","offsetgroup":"Desserts","orientation":"h","showlegend":true,"textposition":"auto","x":[9212],"xaxis":"x","y":["Desserts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Street Food","marker":{"color":"rgb(253,180,98)","pattern":{"shape":""}},"name":"Street Food","offsetgroup":"Street Food","orientation":"h","showlegend":true,"textposition":"auto","x":[7747],"xaxis":"x","y":["Street Food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biryani","marker":{"color":"rgb(179,222,105)","pattern":{"shape":""}},"name":"Biryani","offsetgroup":"Biryani","orientation":"h","showlegend":true,"textposition":"auto","x":[7482],"xaxis":"x","y":["Biryani"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pizza","marker":{"color":"rgb(252,205,229)","pattern":{"shape":""}},"name":"Pizza","offsetgroup":"Pizza","orientation":"h","showlegend":true,"textposition":"auto","x":[6711],"xaxis":"x","y":["Pizza"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Indian","marker":{"color":"rgb(217,217,217)","pattern":{"shape":""}},"name":"South Indian","offsetgroup":"South Indian","orientation":"h","showlegend":true,"textposition":"auto","x":[5898],"xaxis":"x","y":["South Indian"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate" ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

cuisine_text = ', '.join(df['Cuisine'].dropna())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cuisine_text)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
df
# Out:
#                            Restaurant Name  Rating  \
# 0                            Campus Bakers     4.3
# 1           Mama Chicken Mama Franky House     4.0
# 2         GMB - Gopika Sweets & Restaurant     4.2
# 3      Shree Bankey Bihari Misthan Bhandar     4.2
# 4                              Burger King     4.2
# ...                                    ...     ...
# 44886                              Bowl 99     0.0
# 44887                           Vegan Mart     0.0
# 44888                        Biryani Plaza     0.0
# 44889                        Biryani Plaza     0.0
# 44890                        Biryani Plaza     0.0
#
#                                                  Cuisine  Average Price  \
# 0             Bakery, Fast Food, Pizza, Sandwich, Burger             50
# 1            North Indian, Mughlai, Rolls, Burger, Momos             50
# 2      North Indian, South Indian, Chinese, Fast Food...             50
# 3      Mithai, Street Food, South Indian, Chinese, Ic...             50
# 4                           Burger, Fast Food, Beverages             50
# ...                                                  ...            ...
# 44886                                       North Indian            350
# 44887                                  Juices, Beverages            350
# 44888                                            Biryani            350
# 44889                                            Biryani            350
# 44890                                            Biryani            350
#
#         Average Delivery Time  \
# 0                      36 min
# 1                      22 min
# 2                      27 min
# 3                      28 min
# 4                      26 min
# ...                       ...
# 44886  Opens tomorrow at 11am
# 44887  Opens tomorrow at 11am
# 44888  Opens tomorrow at 11am
# 44889  Opens tomorrow at 11am
# 44890  Opens tomorrow at 11am
#
#                                           Safety Measure  Location  \
# 0                Restaurant partner follows WHO protocol      Agra
# 1      Follows all Max Safety measures to ensure your...      Agra
# 2      Follows all Max Safety measures to ensure your...      Agra
# 3                Restaurant partner follows WHO protocol      Agra
# 4      Follows all Max Safety measures to ensure your...      Agra
# ...                                                  ...       ...
# 44886  Follows all Max Safety measures to ensure your...  Warangal
# 44887  Follows all Max Safety measures to ensure your...  Warangal
# 44888  Follows all Max Safety measures to ensure your...  Warangal
# 44889  Follows all Max Safety measures to ensure your...  Warangal
# 44890  Follows all Max Safety measures to ensure your...  Warangal
#
#       Delivery Status Rating Category
# 0                Open              4+
# 1                Open              4+
# 2                Open              4+
# 3                Open              4+
# 4                Open              4+
# ...               ...             ...
# 44886          Closed             0-3
# 44887          Closed             0-3
# 44888          Closed             0-3
# 44889          Closed             0-3
# 44890          Closed             0-3
#
# [44891 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

average_price = df['Average Price']
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')

# Define rating categories
def categorize_rating(rating):
    if rating < 3:
        return '<3'
    elif 3 <= rating < 4:
        return '3-4'
    else:
        return '4+'

df['Rating Category'] = df['Rating'].apply(categorize_rating)

# Define a color palette for each category
palette = {'<3': 'red', '3-4': 'orange', '4+': 'green'}

plt.figure(figsize=(10, 6))
sns.scatterplot(x=average_price, y=df['Rating'], hue=df['Rating Category'], palette=palette, alpha=0.7)
plt.title('Relation between Average Price and Rating')
plt.xlabel('Average Price')
plt.ylabel('Rating')
plt.legend(title='Rating Category')
plt.show()

# %%
import re

# Assuming your DataFrame is named 'df' and has a column 'Average Delivery Time'
# Replace with the actual column name if it's different

# Define a lambda function to extract numeric values from strings with 'min', otherwise set to -1
df['Delivery Time (Numeric)'] = df['Average Delivery Time'].apply(lambda x: int(re.search(r'\d+', str(x)).group()) if 'min' in str(x) else -1)

# Select relevant columns
heatmap_data = df[['Rating', 'Average Price', 'Delivery Time (Numeric)']]

# Create a heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(heatmap_data.corr(), annot=True, cmap="coolwarm", fmt=".2f")

# Customize the plot
heatmap.set_title("Correlation Heatmap - Rating, Average Price, and Delivery Time (Numeric)", pad=20)

# Show the plot
plt.show()

# %%
import pandas as pd
import plotly.express as px
from geopy.geocoders import ArcGIS


df = df[df['Location'] != '-']
restaurant_count = df.groupby("Location")["Restaurant Name"].count().reset_index(name='count')

nom = ArcGIS()
restaurant_count[["Lat", "Long"]] = restaurant_count['Location'].apply(lambda x: nom.geocode(x)[1]).apply(pd.Series)

fig = px.scatter_mapbox(
    restaurant_count,
    lon='Long',
    lat='Lat',
    zoom=3,
    color='Location',
    size='count',
    title='Restaurant Distribution Across Locations',
    mapbox_style='open-street-map',
)

fig.update_layout(margin={"r": 0, 't': 50, 'l': 0, 'b': 10})
fig.show()
# Out:
# <div>                            <div id="113c953a-d4ad-49bf-905c-bcc09353bf69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("113c953a-d4ad-49bf-905c-bcc09353bf69")) {                    Plotly.newPlot(                        "113c953a-d4ad-49bf-905c-bcc09353bf69",                        [{"hovertemplate":"Location=Agra\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[27.19219],"legendgroup":"Agra","lon":[78.00005],"marker":{"color":"#636efa","size":[600],"sizemode":"area","sizeref":3.24},"mode":"markers","name":"Agra","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Ahmedabad\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[23.02778],"legendgroup":"Ahmedabad","lon":[72.60026],"marker":{"color":"#EF553B","size":[600],"sizemode":"area","sizeref":3.24},"mode":"markers","name":"Ahmedabad","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Ajmer\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[26.46554],"legendgroup":"Ajmer","lon":[74.63173],"marker":{"color":"#00cc96","size":[416],"sizemode":"area","sizeref":3.24},"mode":"markers","name":"Ajmer","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Alappuzha\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[9.5013],"legendgroup":"Alappuzha","lon":[76.33233],"marker":{"color":"#ab63fa","size":[54],"sizemode":"area","sizeref":3.24},"mode":"markers","name":"Alappuzha","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Aligarh\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[27.88636],"legendgroup":"Aligarh","lon":[78.07375],"marker":{"color":"#FFA15A","size":[324],"sizemode":"area","sizeref":3.24},"mode":"markers","name":"Aligarh","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Allahabad\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[25.43609],"legendgroup":"Allahabad","lon":[81.84718],"marker":{"color":"#19d3f3","size":[648],"sizemode":"area","sizeref":3.24},"mode":"markers","name":"Allahabad","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Amravati\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[20.93333],"legendgroup":"Amravati","lon":[77.75],"marker":{"color":"#FF6692","size":[352],"sizemode":"area","sizeref":3.24},"mode":"markers","name":"Amravati","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Amritsar\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[31.63347],"legendgroup":"Amritsar","lon":[74.87507],"marker":{"color":"#B6E880","size":[624],"sizemode":"area","sizeref":3.24},"mode":"markers","name":"Amritsar","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Asansol\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[23.6856],"legendgroup":"Asansol","lon":[86.97926],"marker":{"color":"#FF97FF","size":[108],"sizemode":"area","sizeref":3.24},"mode":"markers","name":"Asansol","showlegend":true,"subplot":"mapbox","type":" ...

# %%
import pandas as pd
import plotly.express as px
from geopy.geocoders import ArcGIS

# Assuming your data is in a DataFrame named 'df'
# Replace 'Location' with the actual column name from your dataset

# Filter out rows with '-' location (if applicable)
df = df[df['Location'] != '-']

# Group by Location and get the count of restaurants
restaurant_count = df.groupby("Location")["Restaurant Name"].count().reset_index(name='count')

# Geocode locations using ArcGIS
nom = ArcGIS()
restaurant_count[["Lat", "Long"]] = restaurant_count['Location'].apply(lambda x: nom.geocode(x)[1]).apply(pd.Series)

# Create a heatmap on Mapbox
fig = px.density_mapbox(
    restaurant_count.dropna(subset=['Lat', 'Long']),
    lat='Lat',
    lon='Long',
    z='count',
    radius=10,  # Adjust the radius as needed
    zoom=4,
    mapbox_style="carto-positron",  # You can try other mapbox styles
    title='Restaurant Heatmap in India',
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="8c6d5a70-b6e2-485b-8d62-ad02ff3114fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("